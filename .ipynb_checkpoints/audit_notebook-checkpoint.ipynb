# %% [markdown]
# Data is sourced from this Kaggle Competition: https://www.kaggle.com/competitions/home-credit-credit-risk-model-stability
#
# Directory for running this notebook should look like this: /rds_project/python_code/audit_notebook.ipynb
#
# Directory for storing the data accessed in this notebook should look like this: /rds_project/data
#
# All four items from the Kaggle Data section (csv_files and parquet_files as folder; feature_definitions and sample_submission as csv) should be inside the /rds_project/data/ folder.

# %% [markdown]
# **Data Loading Section**

# %%
import os
import gc
from glob import glob
from pathlib import Path
from datetime import datetime
import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import lightgbm as lgb

from sklearn.model_selection import StratifiedGroupKFold, train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import VotingClassifier
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import exploratory_data_analysis as data_nb
from exploratory_data_analysis import Aggregator

data_nb.Aggregator.group_aggregators = [pl.n_unique] #pl.max, pl.min, 
# data_nb.Aggregator.str_aggregators = [pl.max, pl.min, pl.first, pl.last, pl.n_unique]
# train_df = data_nb.prepare_df(data_nb.CFG.train_dir)
base_files = [
    "_static_cb_0.parquet",
    "_static_0_*.parquet",
    "_applprev_1_*.parquet",
    "_tax_registry_a_1.parquet",
    "_tax_registry_b_1.parquet",
    "_tax_registry_c_1.parquet",
    "_other_1.parquet",
    "_person_1.parquet",
    "_deposit_1.parquet",
    "_debitcard_1.parquet",
    "_credit_bureau_b_1.parquet",
    "_credit_bureau_b_2.parquet",
]
base_agg = Aggregator(
    num_aggregators = [pl.max, pl.min, pl.first, pl.last, pl.mean],
    str_aggregators = [pl.max, pl.min, pl.first, pl.last],
    group_aggregators = [pl.max, pl.min, pl.first, pl.last],
    str_mode = True
)
breakpoint()
train_df = data_nb.prepare_df(base_files, data_nb.CFG.train_dir, base_agg)

# train_df = pd.read_parquet('/kaggle/usr/lib/home_credit_baseline_data/train_full.parquet')
cat_cols = list(train_df.select_dtypes("category").columns)
# Out:
# Collecting data...
#   files:  train_base.parquet
#   chunk:  0
#   files:  _static_cb_0.parquet (depth: 0)
#   chunk:  0
#   files:  _static_0_*.parquet (depth: 0)
#   chunk:  0
#   chunk:  1
#   files:  _applprev_1_*.parquet (depth: 1)
#   chunk:  0
#   chunk:  1
#   agg, depth 1
#   files:  _tax_registry_a_1.parquet (depth: 1)
#   chunk:  0
#   agg, depth 1
#   files:  _tax_registry_b_1.parquet (depth: 1)
#   chunk:  0
#   agg, depth 1
#   files:  _tax_registry_c_1.parquet (depth: 1)
#   chunk:  0
#   agg, depth 1
#   files:  _other_1.parquet (depth: 1)
#   chunk:  0
#   agg, depth 1
#   files:  _person_1.parquet (depth: 1)
#   chunk:  0
#   agg, depth 1
#   files:  _deposit_1.parquet (depth: 1)
#   chunk:  0
#   agg, depth 1
#   files:  _debitcard_1.parquet (depth: 1)
#   chunk:  0
#   agg, depth 1
#   files:  _credit_bureau_b_1.parquet (depth: 1)
#   chunk:  0
#   agg, depth 1
#   files:  _credit_bureau_b_2.parquet (depth: 2)
#   chunk:  0
#   agg, depth 2
#   feats_df shape:	 (1526659, 927)
# Feature Engineering...
# Filter cols...
#   feats_df shape:	 (1526659, 517)
# Convert to pandas...

# %%
train_df.shape
# Out:
# (1526659, 517)

# %%
train_df.describe()
# Out:
#             case_id      WEEK_NUM        target  month_decision  \
# count  1.526659e+06  1.526659e+06  1.526659e+06    1.526659e+06
# mean   1.286077e+06  4.076904e+01  3.143728e-02    6.425584e+00
# std    7.189466e+05  2.379798e+01  1.744964e-01    3.512803e+00
# min    0.000000e+00  0.000000e+00  0.000000e+
#        maxdbddpdtollast6m_4187119P  maxdebt4_972A  maxdpdfrom6mto36m_3546853P  \
# count                650383.000000   1.220640e+06                1.183284e+06
# mean                     48.514143   4.839761e+04                3.241556e+01
# std                     434.620883   5.339889e+04                2.470706e+02
# min                   -1225.000000   0.000000e+00                0.000000e+00
# 25%                      -2.000000   7.112972e+03                0.000000e+00
# 50%                       0.000000   3.296570e+04                0.000000e+00
# 75%                       1.000000   7.032156e+04                2.000000e+00
# max                    4804.000000   1.740000e+06                4.465000e+03
#
#        maxdpdinstldate_3546855D  maxdpdinstlnum_3546846P  maxdpdlast12m_727P  \
# count             700659.000000            697257.000000        1.220640e+06
# mean               -1006.593040                 8.254667        1.660224e+01
# std                 1209.845462                 6.003638        1.926421e+02
# min                -5271.000000                 0.000000        0.000000e+00
# 25%                -1407.000000                 4.000000        0.000000e+00
# 50%                 -495.000000                 7.000000        0.000000e+00
# 75%                 -162.000000                11.000000        0.000000e+00
# max                   13.000000               105.000000        4.629000e+03
#
#        maxdpdlast24m_143P  maxdpdlast3m_392P  maxdpdlast6m_474P  \
# count        1.220640e+06       1.220640e+06       1.220640e+06
# mean         2.637945e+01       6.660291e+00       1.006226e+01
# std          2.310953e+02       1.377646e+02       1.587448e+02
# min          0.000000e+00       0.000000e+00       0.000000e+00
# 25%          0.000000e+00       0.000000e+00       0.000000e+00
# 50%          0.000000e+00       0.000000e+00       0.000000e+00
# 75%          2.000000e+00       0.000000e+00       0.000000e+00
# max          4.629000e+03       4.629000e+03       4.629000e+03
#
#        maxdpdlast9m_1059P  maxdpdtolerance_374P  maxinstallast24m_3658928A  \
# count        1.220640e+06          1.220640e+06               9.017840e+05
# mean         1.342165e+01          5.343590e+01               1.539411e+04
# std          1.769548e+02          2.847601e+02               2.543173e+04
# min          0.000000e+00          0.000000e+00               0.000000e+00
# 25%          0.000000e+00          0.000000e+00               3.258400e+03
# 50%          0.000000e+00          1.000000e+00               6.648600e+03
# 75%          0.000000e+00          8.000000e+00               1.519845e+04
# max          4.629000e+03          4.629000e+03               1.009601e+06
#
#        maxlnamtstart6m_4525199A  maxoutstandbalancel12m_4187113A  \
# count             493803.000000                     7.597010e+05
# mean               44908.547229                     7.136399e+04
# std                38071.827101                     8.186797e+04
# min                    0.000000                    -7.588198e+06
# 25%                19399.000500                     2.006400e+04
# 50%                32934.600000                     4.252040e+04
# 75%                58313.701000                     9.002600e+04
# max               518629.600000                     1.235313e+06
#
#        maxpmtlast3m_4525190A  mindbddpdlast24m_3658935P  \
# count          397329.000000              913457.000000
# mean             9970.821435                  -0.344706
# std             18769.595082                 303.534025
# min                 0.000000               -1284.000000
# 25%              2566.600000                 -36.000000
# 50%              4904.000000                 -17.000000
# 75%              9300.800000                  -7.000000
# max            538113.000000                4709.000000
#
#        mindbdtollast24m_4525191P  mobilephncnt_593L  monthsannuity_845L  \
# count              553832.000000       1.526659e+06        1.074066e+06
# mean                   -1.384097       1.772637e+00        2.584232e+01
# std                   306.376376       1.133040e+00        2.295623e+01
# min                 -1284.000000       0.000000e+00        0.000000e+00
# 25%                   -38.000000       1.000000e+00        9.000000e+00
# 50%                   -17.000000       1.000000e+00        1.800000e+01
# 75%                    -7.000000       2.000000e+00        3.500000e+01
# max                  4709.000000       2.300000e+01        1.670000e+02
#
#        numactivecreds_622L  numactivecredschannel_414L  \
# count         1.526659e+06                1.526659e+06
# mean          4.705812e-01                1.018210e-01
# std           7.083306e-01                3.253375e-01
# min           0.000000e+00                0.000000e+00
# 25%           0.000000e+00                0.000000e+00
# 50%           0.000000e+00                0.000000e+00
# 75%           1.000000e+00                0.000000e+00
# max           7.000000e+00                4.000000e+00
#
#        numactiverelcontr_750L  numcontrs3months_479L  \
# count            1.526659e+06           1.526659e+06
# mean             2.434931e-01           2.710003e-01
# std              4.719501e-01           7.902546e-01
# min              0.000000e+00           0.000000e+00
# 25%              0.000000e+00           0.000000e+00
# 50%              0.000000e+00           0.000000e+00
# 75%              0.000000e+00           0.000000e+00
# max              8.000000e+00           5.800000e+01
#
#        numincomingpmts_3546848L  numinstlallpaidearly3d_817L  numinstls_657L  \
# count              1.071578e+06                 1.080990e+06    1.526655e+06
# mean               3.241246e+01                 2.063139e+01    7.730699e+00
# std                3.293961e+01                 2.569818e+01    1.564890e+01
# min                0.000000e+00                 0.000000e+00    0.000000e+00
# 25%                1.000000e+01                 4.000000e+00    0.000000e+00
# 50%                2.100000e+01                 1.200000e+01    0.000000e+00
# 75%                4.300000e+01                 2.700000e+01    1.200000e+01
# max                8.430000e+02                 3.770000e+02    4.480000e+02
#
#        numinstlsallpaid_934L  numinstlswithdpd10_728L  \
# count           1.080990e+06             1.070164e+06
# mean            2.731751e+01             3.612955e+00
# std             2.980737e+01             1.121828e+01
# min             0.000000e+00             0.000000e+00
# 25%             8.000000e+00             0.000000e+00
# 50%             1.700000e+01             0.000000e+00
# 75%             3.600000e+01             1.000000e+00
# max             3.850000e+02             3.300000e+02
#
#        numinstlswithdpd5_4187116L  numinstlswithoutdpd_562L  \
# count               965535.000000              1.070164e+06
# mean                     2.243969              3.172643e+01
# std                      4.806274              3.288769e+01
# min                      0.000000              0.000000e+00
# 25%                      0.000000              1.000000e+01
# 50%                      0.000000              2.100000e+01
# 75%                      2.000000              4.200000e+01
# max                     89.000000              8.610000e+02
#
#        numinstmatpaidtearly2d_4499204L  numinstpaid_4499208L  \
# count                    679468.000000         679468.000000
# mean                         22.720888             33.473472
# std                          27.310110             33.898698
# min                           0.000000              0.000000
# 25%                           5.000000             11.000000
# 50%                          13.000000             22.000000
# 75%                          29.000000             44.000000
# max                         347.000000            393.000000
#
#        numinstpaidearly3d_3546850L  numinstpaidearly3dest_4493216L  \
# count                 1.079676e+06                   686013.000000
# mean                  1.989282e+01                       20.467737
# std                   2.474424e+01                       25.303222
# min                   0.000000e+00                        0.000000
# 25%                   4.000000e+00                        4.000000
# 50%                   1.100000e+01                       12.000000
# 75%                   2.600000e+01                       26.000000
# max                   3.730000e+02                      322.000000
#
#        numinstpaidearly5d_1087L  numinstpaidearly5dest_4493211L  \
# count              1.074066e+06                   686013.000000
# mean               4.571860e+00                        3.250481
# std                8.803408e+00                        4.437852
# min                0.000000e+00                        0.000000
# 25%                0.000000e+00                        0.000000
# 50%                2.000000e+00                        2.000000
# 75%                6.000000e+00                        5.000000
# max                2.780000e+02                       59.000000
#
#        numinstpaidearly5dobd_4499205L  numinstpaidearly_338L  \
# count                   679468.000000           1.074066e+06
# mean                        16.504999           1.617541e+01
# std                         22.351270           2.193842e+01
# min                          0.000000           0.000000e+00
# 25%                          3.000000           3.000000e+00
# 50%                          9.000000           9.000000e+00
# 75%                         21.000000           2.100000e+01
# max                        306.000000           3.730000e+02
#
#        numinstpaidearlyest_4493214L  numinstpaidlastcontr_4325080L  \
# count                 686013.000000                  857473.000000
# mean                      16.512078                       7.746829
# std                       22.354492                       6.124473
# min                        0.000000                       0.000000
# 25%                        3.000000                       3.000000
# 50%                        9.000000                       6.000000
# 75%                       21.000000                      12.000000
# max                      306.000000                      77.000000
#
#        numinstpaidlate1d_3546852L  numinstregularpaid_973L  \
# count                1.074066e+06             1.071047e+06
# mean                 5.483400e+00             3.002201e+01
# std                  8.650442e+00             3.228830e+01
# min                  0.000000e+00             0.000000e+00
# 25%                  0.000000e+00             9.000000e+00
# 50%                  2.000000e+00             1.800000e+01
# 75%                  7.000000e+00             3.900000e+01
# max                  1.370000e+02             3.930000e+02
#
#        numinstregularpaidest_4493210L  numinsttopaygr_769L  \
# count                   686013.000000         1.074065e+06
# mean                        33.487330         5.955127e+00
# std                         33.907611         1.018726e+01
# min                          0.000000         0.000000e+00
# 25%                         11.000000         0.000000e+00
# 50%                         22.000000         0.000000e+00
# 75%                         44.000000         9.000000e+00
# max                        393.000000         1.520000e+02
#
#        numinsttopaygrest_4493213L  numinstunpaidmax_3546851L  \
# count               686013.000000               1.074065e+06
# mean                     5.842908               5.409234e+00
# std                     10.197811               8.918626e+00
# min                      0.000000               0.000000e+00
# 25%                      0.000000               0.000000e+00
# 50%                      0.000000               0.000000e+00
# 75%                      8.000000               8.000000e+00
# max                    152.000000               7.200000e+01
#
#        numinstunpaidmaxest_4493212L  numnotactivated_1143L  \
# count                 686013.000000           1.526659e+06
# mean                       5.298333           2.171212e-02
# std                        8.889130           1.573016e-01
# min                        0.000000           0.000000e+00
# 25%                        0.000000           0.000000e+00
# 50%                        0.000000           0.000000e+00
# 75%                        8.000000           0.000000e+00
# max                       72.000000           4.000000e+00
#
#        numpmtchanneldd_318L  numrejects9m_859L  pctinstlsallpaidearl3d_427L  \
# count          1.526659e+06       1.526659e+06                 1.067921e+06
# mean           2.441672e-02       3.687634e-01                 5.988251e-01
# std            1.619722e-01       1.248277e+00                 3.489413e-01
# min            0.000000e+00       0.000000e+00                 0.000000e+00
# 25%            0.000000e+00       0.000000e+00                 3.473700e-01
# 50%            0.000000e+00       0.000000e+00                 6.190500e-01
# 75%            0.000000e+00       0.000000e+00                 8.461500e-01
# max            4.000000e+00       1.530000e+02                 2.300000e+01
#
#        pctinstlsallpaidlat10d_839L  pctinstlsallpaidlate1d_3546856L  \
# min                    0.214000      -134.000000        0.000000e+00
# 25%                 3309.314000       -34.000000        0.000000e+00
# 50%                 6221.200000        -9.000000        0.000000e+00
# 75%                11685.000000         6.000000        0.000000e+00
# max               794899.200000        14.000000        4.206000e+03
#
#        max_annuity_853A  max_credacc_actualbalance_314A  \
# count      1.217920e+06                    2.535730e+05
# mean       5.674026e+03                    2.024050e+04
# std        4.148343e+03                    2.813699e+04
# min        0.000000e+00                   -1.340084e+05
# 25%        3.012200e+03                    2.000000e+00
# 50%        4.834600e+03                    1.039800e+04
# 75%        7.298800e+03                    3.044400e+04
# max        1.051302e+05                    2.540730e+06
#
#        max_credacc_credlmt_575A  max_credacc_maxhisbal_375A  \
# count              1.219218e+06                2.535730e+05
# mean               1.045887e+04               -2.243568e+03
# std                2.610349e+04                3.057587e+04
# min                0.000000e+00               -1.999500e+05
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                4.000000e+00
# max                4.000000e+05                7.988198e+06
#
#        max_credacc_minhisbal_90A  max_credamount_590A  max_currdebt_94A  \
# count              253573.000000         1.219218e+06      1.107653e+06
# mean                -5741.771087         7.164343e+04      1.861947e+04
# std                 16701.759905         5.874366e+04      3.461699e+04
# min               -214424.380000         0.000000e+00      0.000000e+00
# 25%                     0.000000         3.000000e+04      0.000000e+00
# 50%                     0.000000         5.801880e+04      0.000000e+00
# 75%                     0.000000         1.000000e+05      2.272682e+04
# max                239000.000000         1.000000e+06      5.074297e+05
#
#        max_downpmt_134A  max_mainoccupationinc_437A  max_maxdpdtolerance_577P  \
# count      1.219218e+06                1.220298e+06              1.075690e+06
# mean       1.699259e+03                6.467090e+04              4.215834e+01
# std        5.382925e+03                4.009709e+04              2.510519e+02
# min        0.000000e+00                0.000000e+00              0.000000e+00
# 25%        0.000000e+00                3.912000e+04              0.000000e+00
# 50%        0.000000e+00                5.740000e+04              0.000000e+00
# 75%        1.000000e+03                8.000000e+04              5.000000e+00
# max        4.204000e+05                1.996000e+05              4.362000e+03
#
#        max_outstandingdebt_522A  max_revolvingaccount_394A  \
# count              1.106276e+06               2.535770e+05
# mean               2.508224e+04               7.531677e+08
# std                5.362836e+04               5.096239e+07
# min                0.000000e+00               5.403423e+08
# 25%                0.000000e+00               7.426119e+08
# 50%                0.000000e+00               7.605763e+08
# 75%                2.537384e+04               7.805201e+08
# max                1.210629e+06               8.006087e+08
#
#        min_actualdpd_943P  min_annuity_853A  min_credacc_actualbalance_314A  \
# count        1.221505e+06      1.217920e+06                    2.535730e+05
# mean         1.825944e-02      1.705477e+03                    1.695297e+04
# std          7.673556e+00      1.958452e+03                    2.554400e+04
# min          0.000000e+00      0.000000e+00                   -1.340084e+05
# 25%          0.000000e+00      0.000000e+00                    0.000000e+00
# 50%          0.000000e+00      1.358000e+03                    4.477534e+03
# 75%          0.000000e+00      2.350600e+03                    2.547520e+04
# max          4.206000e+03      1.030000e+05                    2.540730e+06
#
#        min_credacc_credlmt_575A  min_credacc_maxhisbal_375A  \
# count              1.219218e+06                2.535730e+05
# mean               1.385994e+03               -3.823440e+03
# std                8.934426e+03                2.765383e+04
# min                0.000000e+00               -2.902651e+05
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                0.000000e+00
# max                4.000000e+05                7.988198e+06
#
#        min_credacc_minhisbal_90A  min_credamount_590A  min_currdebt_94A  \
# count              253573.000000         1.219218e+06      1.107653e+06
# mean                -7196.173839         1.758764e+04      1.982189e+03
# std                 18648.737517         2.116043e+04      1.015413e+04
# min               -350532.600000         0.000000e+00      0.000000e+00
# 25%                 -2116.200000         5.998000e+03      0.000000e+00
# 50%                     0.000000         1.140000e+04      0.000000e+00
# 75%                     0.000000         2.060000e+04      0.000000e+00
# max                199567.000000         4.000000e+05      3.399964e+05
#
#        min_downpmt_134A  min_mainoccupationinc_437A  min_maxdpdtolerance_577P  \
# count      1.219218e+06                1.220298e+06              1.075690e+06
# mean       1.698117e+02                2.459305e+04              1.459260e+01
# std        1.890377e+03                2.232683e+04              1.675705e+02
# min        0.000000e+00                0.000000e+00              0.000000e+00
# 25%        0.000000e+00                9.000000e+03              0.000000e+00
# 50%        0.000000e+00                1.960000e+04              0.000000e+00
# 75%        0.000000e+00                3.200000e+04              0.000000e+00
# max        3.204000e+05                1.996000e+05              4.362000e+03
#
#        min_outstandingdebt_522A  min_revolvingaccount_394A  \
# count              1.106276e+06               2.535770e+05
# mean               2.370576e+03               7.468476e+08
# std                1.333214e+04               5.537653e+07
# min                0.000000e+00               5.403423e+08
# 25%                0.000000e+00               7.416421e+08
# 50%                0.000000e+00               7.604382e+08
# 75%                0.000000e+00               7.803522e+08
# max                6.147498e+05               8.006087e+08
#
#        first_actualdpd_943P  first_annuity_853A  first_credacc_credlmt_575A  \
# count          1.221505e+06        1.217913e+06                1.219213e+06
# mean           1.825944e-02        1.706922e+03                8.427379e+03
# std            7.673556e+00        1.959244e+03                2.251972e+04
# min            0.000000e+00        0.000000e+00                0.000000e+00
# 25%            0.000000e+00        0.000000e+00                0.000000e+00
# 50%            0.000000e+00        1.358000e+03                0.000000e+00
# 75%            0.000000e+00        2.353000e+03                0.000000e+00
# max            4.206000e+03        1.030000e+05                4.000000e+05
#
#        first_credamount_590A  first_currdebt_94A  first_downpmt_134A  \
# count           1.219212e+06       918307.000000        1.219212e+06
# mean            2.490722e+04         3769.622254        5.059082e+02
# std             2.727178e+04        12755.871671        2.751810e+03
# min             0.000000e+00            0.000000        0.000000e+00
# 25%             8.000000e+03            0.000000        0.000000e+00
# 50%             1.660000e+04            0.000000        0.000000e+00
# 75%             3.098810e+04            0.000000        0.000000e+00
# max             4.000000e+05       323806.470000        4.204000e+05
#
#        first_mainoccupationinc_437A  first_maxdpdtolerance_577P  \
# count                  1.149017e+06               815555.000000
# mean                   3.775816e+04                   19.353119
# std                    3.036225e+04                  196.247125
# min                    0.000000e+00                    0.000000
# 25%                    1.600000e+04                    0.000000
# 50%                    3.000000e+04                    0.000000
# 75%                    5.000000e+04                    0.000000
# max                    1.996000e+05                 4362.000000
#
#        first_outstandingdebt_522A  first_revolvingaccount_394A  \
# count               915763.000000                 2.182620e+05
# mean                  4258.545625                 7.644025e+08
# std                  15353.215365                 2.016545e+07
# min                      0.000000                 5.403559e+08
# 25%                      0.000000                 7.427542e+08
# 50%                      0.000000                 7.605669e+08
# 75%                      0.000000                 7.805058e+08
# max                 614749.800000                 8.006087e+08
#
#        last_actualdpd_943P  last_annuity_853A  \
# count         1.219108e+06       1.049002e+06
# mean          7.196409e-02       5.483420e+03
# std           1.068645e+01       4.094210e+03
# min           0.000000e+00       0.000000e+00
# 25%           0.000000e+00       2.875200e+03
# 50%           0.000000e+00       4.624600e+03
# 75%           0.000000e+00       7.009800e+03
# ...
# 25%              5.000000                 0.0               0.00000
# 50%              5.000000                 0.0               2.00000
# 75%              7.000000                 0.0               4.00000
# max            100.000000                 0.0              69.00000
#
#        last_num_group1_1_4  max_pmtamount_36A  min_pmtamount_36A  \
# count        150732.000000      482265.000000      482265.000000
# mean              4.129800        3881.558039        1351.840689
# std               3.457284        4982.169677        1961.067568
# min               0.000000           0.000000           0.000000
# 25%               2.000000        1188.600000         355.200000
# 50%               4.000000        2400.000000         850.000000
# 75%               5.000000        4502.656000        1600.000000
# max              64.000000       87115.600000       42500.000000
#
#        first_pmtamount_36A  last_pmtamount_36A  mean_pmtamount_36A  \
# count        482265.000000       482265.000000       482265.000000
# mean           2482.728235         2329.667668         2354.384004
# std            3388.100784         3225.369090         2809.911518
# min               0.000000            0.000000            0.000000
# 25%             850.000000          800.000000          890.255556
# 50%            1500.000000         1400.000000         1551.000010
# 75%            2895.226000         2687.200000         2714.371429
# max           42500.000000        68760.805000        42500.000000
#
#        max_processingdate_168D  min_processingdate_168D  \
# count            482265.000000            482265.000000
# mean                 -7.794219              -115.232580
# std                  28.835325                64.246346
# min                -183.000000              -184.000000
# 25%                 -12.000000              -158.000000
# 50%                  -1.000000              -146.000000
# 75%                  10.000000              -103.000000
# max                  14.000000                14.000000
#
#        first_processingdate_168D  last_processingdate_168D  \
# count              482265.000000             482265.000000
# mean                   -7.794219               -115.232580
# std                    28.835325                 64.246346
# min                  -183.000000               -184.000000
# 25%                   -12.000000               -158.000000
# 50%                    -1.000000               -146.000000
# 75%                    10.000000               -103.000000
# max                    14.000000                 14.000000
#
#        mean_processingdate_168D  max_num_group1_1_5  min_num_group1_1_5  \
# count             482265.000000       482265.000000            482265.0
# mean                 -61.715847            5.933532                 0.0
# std                   39.201265            3.584104                 0.0
# min                 -183.000000            0.000000                 0.0
# 25%                  -84.000000            4.000000                 0.0
# 50%                  -74.000000            5.000000                 0.0
# 75%                  -54.000000            7.000000                 0.0
# max                   14.000000          120.000000                 0.0
#
#        first_num_group1_1_5  last_num_group1_1_5  max_mainoccupationinc_384A  \
# count              482265.0        482265.000000                1.526659e+06
# mean                    0.0             5.933532                5.770748e+04
# std                     0.0             3.584104                3.334830e+04
# min                     0.0             0.000000                0.000000e+00
# 25%                     0.0             4.000000                3.600000e+04
# 50%                     0.0             5.000000                5.000000e+04
# 75%                     0.0             7.000000                7.000000e+04
# max                     0.0           120.000000                2.000000e+05
#
#        min_mainoccupationinc_384A  first_mainoccupationinc_384A  \
# count                1.526659e+06                  1.516752e+06
# mean                 5.770748e+04                  5.769842e+04
# std                  3.334830e+04                  3.334931e+04
# min                  0.000000e+00                  0.000000e+00
# 25%                  3.600000e+04                  3.600000e+04
# 50%                  5.000000e+04                  5.000000e+04
# 75%                  7.000000e+04                  7.000000e+04
# max                  2.000000e+05                  2.000000e+05
#
#        last_mainoccupationinc_384A  mean_mainoccupationinc_384A  \
# count                776358.000000                 1.526659e+06
# mean                  58945.557871                 5.770748e+04
# std                   33091.894514                 3.334830e+04
# min                       0.000000                 0.000000e+00
# 25%                   36000.000000                 3.600000e+04
# 50%                   50000.000000                 5.000000e+04
# 75%                   70000.000000                 7.000000e+04
# max                  200000.000000                 2.000000e+05
#
#        max_birth_259D  max_empl_employedfrom_271D  min_birth_259D  \
# count    1.526659e+06               566701.000000    1.526659e+06
# mean    -1.627637e+04                -2208.682981   -1.627637e+04
# std      5.124233e+03                 2275.990957    5.124233e+03
# min     -2.777400e+04               -20603.000000   -2.777400e+04
# 25%     -2.052600e+04                -2985.000000   -2.052600e+04
# 50%     -1.563800e+04                -1432.000000   -1.563800e+04
# 75%     -1.195900e+04                 -643.000000   -1.195900e+04
# max     -7.656000e+03                   13.000000   -7.656000e+03
#
#        min_empl_employedfrom_271D  first_birth_259D  \
# count               566701.000000      1.516752e+06
# mean                 -2208.682981     -1.628923e+04
# std                   2275.990957      5.128030e+03
# min                 -20603.000000     -2.777400e+04
# 25%                  -2985.000000     -2.054900e+04
# 50%                  -1432.000000     -1.565900e+04
# 75%                   -643.000000     -1.196600e+04
# max                     13.000000     -7.656000e+03
#
#        first_empl_employedfrom_271D  last_birth_259D  mean_birth_259D  \
# count                 562855.000000    776358.000000     1.526659e+06
# mean                   -2208.108376    -16978.017658    -1.627637e+04
# std                     2277.081733      4994.865416     5.124233e+03
# min                   -20603.000000    -27764.000000    -2.777400e+04
# 25%                    -2982.000000    -21295.000000    -2.052600e+04
# 50%                    -1431.000000    -16380.000000    -1.563800e+04
# 75%                     -643.000000    -12776.000000    -1.195900e+04
# max                       13.000000     -7659.000000    -7.656000e+03
#
#        mean_empl_employedfrom_271D  max_personindex_1023L  \
# count                566701.000000           1.526659e+06
# mean                  -2208.682981           5.273273e-01
# std                    2275.990957           7.304981e-01
# min                  -20603.000000           0.000000e+00
# 25%                   -2985.000000           0.000000e+00
# 50%                   -1432.000000           0.000000e+00
# 75%                    -643.000000           1.000000e+00
# max                      13.000000           6.000000e+00
#
#        max_persontype_1072L  max_persontype_792L  min_personindex_1023L  \
# count          1.526659e+06         1.526659e+06              1526659.0
# mean           2.486625e+00         2.486625e+00                    0.0
# std            1.884311e+00         1.884311e+00                    0.0
# min            1.000000e+00         1.000000e+00                    0.0
# 25%            1.000000e+00         1.000000e+00                    0.0
# 50%            1.000000e+00         1.000000e+00                    0.0
# 75%            5.000000e+00         5.000000e+00                    0.0
# max            5.000000e+00         5.000000e+00                    0.0
#
#        min_persontype_1072L  min_persontype_792L  first_personindex_1023L  \
# count             1526659.0            1526659.0             1.520187e+06
# 25%              -1970.000000           -1911.000000           -1913.000000
# 50%              -1668.000000           -1573.000000           -1615.000000
# 75%              -1303.000000           -1206.000000           -1288.000000
# max               -524.000000            -524.000000            -524.000000
#
#        max_num_group1_1_8  min_num_group1_1_8  first_num_group1_1_8  \
# count       105111.000000            105111.0         105111.000000
# mean             0.380312                 0.0              0.063247
# std              0.957900                 0.0              0.271178
# min              0.000000                 0.0              0.000000
# 25%              0.000000                 0.0              0.000000
# 50%              0.000000                 0.0              0.000000
# 75%              0.000000                 0.0              0.000000
# max             64.000000                 0.0              8.000000
#
#        last_num_group1_1_8  max_openingdate_857D  min_openingdate_857D  \
# count        105111.000000         105087.000000         105087.000000
# mean              0.291482          -1541.167280          -1660.075309
# std               0.833975            448.678936            443.956800
# min               0.000000          -6376.000000          -6634.000000
# 25%               0.000000          -1887.000000          -1991.000000
# 50%               0.000000          -1539.000000          -1708.000000
# 75%               0.000000          -1195.000000          -1339.000000
# max              64.000000           -524.000000           -524.000000
#
#        first_openingdate_857D  last_openingdate_857D  mean_openingdate_857D  \
# count           100972.000000          104690.000000          105087.000000
# mean             -1643.931793           -1558.338705           -1600.797577
# std                445.818307             448.035989             425.306615
# min              -6436.000000           -6376.000000           -6376.000000
# 25%              -1978.000000           -1903.000000           -1914.000000
# 50%              -1683.000000           -1567.000000           -1618.000000
# 75%              -1317.000000           -1213.000000           -1296.000000
# max               -524.000000            -524.000000            -524.000000
#
#        max_num_group1_1_9  min_num_group1_1_9  first_num_group1_1_9  \
# count       111772.000000            111772.0         111772.000000
# mean             0.407347                 0.0              0.003579
# std              0.986336                 0.0              0.068114
# min              0.000000                 0.0              0.000000
# 25%              0.000000                 0.0              0.000000
# 50%              0.000000                 0.0              0.000000
# 75%              1.000000                 0.0              0.000000
# max             65.000000                 0.0              6.000000
#
#        last_num_group1_1_9
# count        111772.000000
# mean              0.405987
# std               0.986035
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               1.000000
# max              65.000000

# %% [markdown]
# **Sensitive Features to Test**

# %%
train_df['first_sex_738L']
# Out:
# 0          F
# 1          M
# 2          F
# 3          F
# 4          F
#           ..
# 1526654    F
# 1526655    F
# 1526656    M
# 1526657    F
# 1526658    F
# Name: first_sex_738L, Length: 1526659, dtype: category
# Categories (2, object): ['F', 'M']

# %%
train_df['first_language1_981M']
# Out:
# 0            P10_39_147
# 1            P10_39_147
# 2            P10_39_147
# 3            P10_39_147
# 4            P10_39_147
#                ...
# 1526654    P209_127_106
# 1526655    P209_127_106
# 1526656    P209_127_106
# 1526657    P209_127_106
# 1526658      P10_39_147
# Name: first_language1_981M, Length: 1526659, dtype: category
# Categories (3, object): ['P10_39_147', 'P209_127_106', 'a55475b1']

# %%
train_df['maritalst_385M']
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1526654    a55475b1
# 1526655    a55475b1
# 1526656    a55475b1
# 1526657    3439d993
# 1526658    b6cabe76
# Name: maritalst_385M, Length: 1526659, dtype: category
# Categories (6, object): ['3439d993', '38c061ee', 'a55475b1', 'a7fcb6e5', 'b6cabe76', 'ecd83604']

# %%
train_df['education_1103M']
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1526654    a55475b1
# 1526655    a55475b1
# 1526656    a55475b1
# 1526657    6b2ae0fa
# 1526658    a55475b1
# Name: education_1103M, Length: 1526659, dtype: category
# Categories (5, object): ['39a0853f', '6b2ae0fa', '717ddd49', 'a55475b1', 'c8e1a1d0']

# %%
train_df['dateofbirth_337D']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 1526654   -22193.0
# 1526655   -25541.0
# 1526656   -15771.0
# 1526657   -25814.0
# 1526658   -26485.0
# Name: dateofbirth_337D, Length: 1526659, dtype: float64

# %% [markdown]
# Class Imbalance Analysis

# %%
np.unique(train_df['target'], return_counts=True)
# Out:
# (array([0, 1]), array([1478665,   47994]))

# %%
np.unique(train_df['min_sex_738L'], return_counts=True)
# Out:
# (array(['F', 'M'], dtype=object), array([952776, 573883]))

# %%
1478665/(1578665+47994)
# Out:
# 0.9090196531663981

# %% [markdown]
# **Training Section**

# %%
from sklearn.model_selection import train_test_split

# %%
train_df, valid_df = train_test_split(train_df, test_size=0.1, random_state=42) #Need Validation set for ADS analysis

# %%
y_valid = valid_df['target']

# %%
def gini_stability(base, score_col="score", w_fallingrate=88.0, w_resstd=-0.5):
    gini_in_time = base.loc[:, ["WEEK_NUM", "target", score_col]]\
        .sort_values("WEEK_NUM")\
        .groupby("WEEK_NUM")[["target", score_col]]\
        .apply(lambda x: 2*roc_auc_score(x["target"], x[score_col])-1).tolist()
    
    x = np.arange(len(gini_in_time))
    y = gini_in_time
    a, b = np.polyfit(x, y, 1)
    y_hat = a*x + b
    residuals = y - y_hat
    res_std = np.std(residuals)
    avg_gini = np.mean(gini_in_time)
    return avg_gini + w_fallingrate * min(0, a) + w_resstd * res_std

# %%
# %%time
X = train_df.drop(columns=["target", "case_id", "WEEK_NUM"])
print("X shape: ", X.shape)
y = train_df["target"]
weeks = train_df["WEEK_NUM"]

cv = StratifiedGroupKFold(n_splits=5, shuffle=False)

params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    "metric": "auc",
    "max_depth": 8,
    "max_bin": 255,
    "learning_rate": 0.05,
    "n_estimators": 1000,
    "colsample_bytree": 0.8, 
    "colsample_bynode": 0.8,
    "verbose": -1,
    "random_state": 42,
    "device": "gpu",
}

fitted_models = []
oof_pred = np.zeros(X.shape[0])

for idx_train, idx_valid in cv.split(X, y, groups=weeks):
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

    model = lgb.LGBMClassifier(**params)
    model.fit(
        X_train, y_train,
        eval_set=[(X_valid, y_valid)],
        callbacks=[lgb.log_evaluation(100), lgb.early_stopping(100)]
    )
    fitted_models.append(model)
    val_pred = model.predict_proba(X_valid)[:, 1]
    oof_pred[idx_valid] = val_pred
    gc.collect()
# Out:
# X shape:  (1373993, 514)
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.818275
# [200]	valid_0's auc: 0.827049
# [300]	valid_0's auc: 0.830166
# [400]	valid_0's auc: 0.831188
# [500]	valid_0's auc: 0.831532
# [600]	valid_0's auc: 0.831921
# [700]	valid_0's auc: 0.832028
# [800]	valid_0's auc: 0.832256
# [900]	valid_0's auc: 0.832459
# [1000]	valid_0's auc: 0.832569
# Did not meet early stopping. Best iteration is:
# [979]	valid_0's auc: 0.832598
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.826333
# [200]	valid_0's auc: 0.835026
# [300]	valid_0's auc: 0.838106
# [400]	valid_0's auc: 0.839036
# [500]	valid_0's auc: 0.839337
# [600]	valid_0's auc: 0.839563
# [700]	valid_0's auc: 0.839757
# [800]	valid_0's auc: 0.839719
# Early stopping, best iteration is:
# [709]	valid_0's auc: 0.839771
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.820499
# [200]	valid_0's auc: 0.828826
# [300]	valid_0's auc: 0.831585
# [400]	valid_0's auc: 0.832602
# [500]	valid_0's auc: 0.83326
# [600]	valid_0's auc: 0.83357
# [700]	valid_0's auc: 0.833873
# [800]	valid_0's auc: 0.833973
# [900]	valid_0's auc: 0.834236
# Early stopping, best iteration is:
# [882]	valid_0's auc: 0.834238
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.817069
# [200]	valid_0's auc: 0.824989
# [300]	valid_0's auc: 0.827945
# [400]	valid_0's auc: 0.828903
# [500]	valid_0's auc: 0.829306
# [600]	valid_0's auc: 0.82977
# [700]	valid_0's auc: 0.829815
# [800]	valid_0's auc: 0.829991
# [900]	valid_0's auc: 0.83013
# [1000]	valid_0's auc: 0.830194
# Did not meet early stopping. Best iteration is:
# [963]	valid_0's auc: 0.830284
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.818175
# [200]	valid_0's auc: 0.827243
# [300]	valid_0's auc: 0.830436
# [400]	valid_0's auc: 0.831626
# [500]	valid_0's auc: 0.832289
# [600]	valid_0's auc: 0.832716
# [700]	valid_0's auc: 0.832753
# [800]	valid_0's auc: 0.832866
# [900]	valid_0's auc: 0.832892
# [1000]	valid_0's auc: 0.832936
# Did not meet early stopping. Best iteration is:
# [978]	valid_0's auc: 0.832991
# CPU times: user 20min 24s, sys: 26.3 s, total: 20min 50s
# Wall time: 21min 3s

# %% [markdown]
# **Accuracy Measures**

# %%
oof_models_dict = [(str(i), model) for i, model in enumerate(fitted_models)]

model = VotingClassifier(
    estimators=oof_models_dict,
    voting='soft',
)
model.estimators_ = fitted_models
model.le_ = LabelEncoder().fit(y)
model.classes_ = model.le_.classes_

# %%
valid_preds = model.predict(valid_df.drop(columns=["target", "case_id", "WEEK_NUM"]))
print(valid_preds.shape)
print(valid_df.shape)
valid_preds_proba = model.predict_proba(valid_df.drop(columns=["target", "case_id", "WEEK_NUM"]))[:,1]
# Out:
# (152666,)
# (152666, 517)

# %%
np.unique(np.round(valid_preds), return_counts=True)
# Out:
# (array([0, 1]), array([152557,    109]))

# %%
np.unique(np.round(valid_preds_proba), return_counts=True)
# Out:
# (array([0., 1.]), array([152557,    109]))

# %%
y_valid = valid_df['target']
print(y_valid.shape)
# Out:
# (152666,)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
print("Accuracy: ", accuracy_score(y_valid, np.round(valid_preds)))
print("Recall: ", recall_score(y_valid, np.round(valid_preds)))
print("Precision: ", precision_score(y_valid, np.round(valid_preds)))
print("F1 Score: ", f1_score(y_valid, np.round(valid_preds)))
# Out:
# Accuracy:  0.9692203896086883
# Recall:  0.012324691882702932
# Precision:  0.5321100917431193
# F1 Score:  0.024091381100726898

# %%
oof_df = valid_df[["WEEK_NUM", "target"]].copy()
oof_df["pred_oof"] = valid_preds_proba
gini_score = gini_stability(oof_df, score_col="pred_oof")
print("gini_score:\t", gini_score)
# Out:
# gini_score:	 0.6418694607963445

# %%
roc_auc_oof = roc_auc_score(y_valid, valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
# Out:
# CV roc_auc_oof:  0.8382260967603953

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(y_valid, np.round(valid_preds)).ravel()
print("Confusion Matrix: ", confusion_matrix(y_valid, np.round(valid_preds)))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Confusion Matrix:  [[147909     51]
#  [  4648     58]]
# FPR:  0.0003446877534468775
# FNR:  0.9876753081172971

# %%
sns.heatmap(confusion_matrix(y_valid, np.round(valid_preds)), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
# Categorize age into bins and combine with sex
valid_df['age_bucket'] = pd.cut(valid_df['dateofbirth_337D'].abs()/365, bins=[0, 30, 40, 50, 60, 200], labels=['<30', '30-40', '40-50', '50-60', '>60'], right=False)
valid_df['group_age_sex'] = valid_df['first_sex_738L'].astype(str) + ' & ' + valid_df['age_bucket'].astype(str)

# Dictionary to hold each group's DataFrame
group_dfs = {}

# Iterate over each unique group and create a DataFrame
for group in valid_df['group_age_sex'].unique():
    group_dfs[group] = valid_df[valid_df['group_age_sex'] == group]

male_idx = valid_df.drop(valid_df[valid_df['first_sex_738L'] != "M"].index)
female_idx = valid_df.drop(valid_df[valid_df['first_sex_738L'] != 'F'].index)
language_idx_1 = valid_df.drop(valid_df[valid_df['first_language1_981M'] != 'P10_39_147'].index)
language_idx_2 = valid_df.drop(valid_df[valid_df['first_language1_981M'] != 'P209_127_106'].index)
language_idx_other = valid_df.drop(valid_df[valid_df['first_language1_981M'] != 'a55475b1'].index)
marital_idx_1 = valid_df.drop(valid_df[valid_df['maritalst_385M'] != '3439d993'].index)
marital_idx_2 = valid_df.drop(valid_df[valid_df['maritalst_385M'] != '38c061ee'].index)
marital_idx_3 = valid_df.drop(valid_df[valid_df['maritalst_385M'] != 'a7fcb6e5'].index)
marital_idx_4 = valid_df.drop(valid_df[valid_df['maritalst_385M'] != 'b6cabe76'].index)
marital_idx_5 = valid_df.drop(valid_df[valid_df['maritalst_385M'] != 'ecd83604'].index)
marital_idx_other = valid_df.drop(valid_df[valid_df['maritalst_385M'] != 'a55475b1'].index)
education_idx_1 = valid_df.drop(valid_df[valid_df['education_1103M'] != '39a0853f'].index)
education_idx_2 = valid_df.drop(valid_df[valid_df['education_1103M'] != '6b2ae0fa'].index)
education_idx_3 = valid_df.drop(valid_df[valid_df['education_1103M'] != '717ddd49'].index)
education_idx_4 = valid_df.drop(valid_df[valid_df['education_1103M'] != 'c8e1a1d0'].index)
education_idx_other = valid_df.drop(valid_df[valid_df['education_1103M'] != 'a55475b1'].index)

# %%
#Male Section
print("Male Section")
new_idx_df = male_idx
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Male Section
# Accuracy:  0.9621818689273816
# Recall:  0.016069788797061526
# Precision:  0.5833333333333334
# F1 Score:  0.031277926720285974
# gini_score:	 0.5865660186705102
# CV roc_auc_oof:  0.8225127099952161
# Confusion Matrix:
#  [[55124    25]
#  [ 2143    35]]
# FPR:  0.0004533173765616784
# FNR:  0.9839302112029384

# %%
print("Female Section")
new_idx_df = female_idx
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Female Section
# Accuracy:  0.9735423396706032
# Recall:  0.009218436873747494
# Precision:  0.46938775510204084
# F1 Score:  0.018081761006289308
# Gini Score code error.
# CV roc_auc_oof:  0.8455599275138616
# Confusion Matrix:
#  [[91894    26]
#  [ 2472    23]]
# FPR:  0.0002828546562228024
# FNR:  0.9907815631262525

# %%
print("Language 1 Section")
new_idx_df = language_idx_1
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Language 1 Section
# Accuracy:  0.9663751329630067
# Recall:  0.013366162504396765
# Precision:  0.48717948717948717
# F1 Score:  0.026018486819582336
# gini_score:	 0.628427269397833
# CV roc_auc_oof:  0.8305248984355963
# Confusion Matrix:
#  [[81727    40]
#  [ 2805    38]]
# FPR:  0.0004891949074810132
# FNR:  0.9866338374956032

# %%
print("Language 2 Section")
new_idx_df = language_idx_2
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Language 2 Section
# Accuracy:  0.972530969984821
# Recall:  0.008886255924170616
# Precision:  0.6
# F1 Score:  0.017513134851138354
# Gini Score code error.
# CV roc_auc_oof:  0.8438964785761801
# Confusion Matrix:
#  [[59571    10]
#  [ 1673    15]]
# FPR:  0.00016783874053809101
# FNR:  0.9911137440758294

# %%
print("Language Other Section")
new_idx_df = language_idx_other
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Language Other Section
# Accuracy:  0.9748047738323266
# Recall:  0.02857142857142857
# Precision:  0.8333333333333334
# F1 Score:  0.05524861878453038
# Gini Score code error.
# CV roc_auc_oof:  0.8772638492783682
# Confusion Matrix:
#  [[6611    1]
#  [ 170    5]]
# FPR:  0.00015124016938898973
# FNR:  0.9714285714285714

# %%
print("Marital 1 Section")
new_idx_df = marital_idx_1
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Marital 1 Section
# Accuracy:  0.9719140901581308
# Recall:  0.013574660633484163
# Precision:  0.5
# F1 Score:  0.026431718061674013
# Gini Score code error.
# CV roc_auc_oof:  0.8476726388070251
# Confusion Matrix:
#  [[53513    21]
#  [ 1526    21]]
# FPR:  0.0003922740688160795
# FNR:  0.9864253393665159

# %%
print("Marital 2 Section")
new_idx_df = marital_idx_2
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Marital 2 Section
# Accuracy:  0.9662878787878788
# Recall:  0.0
# Precision:  0.0
# F1 Score:  0.0
# Gini Score code error.
# CV roc_auc_oof:  0.8342209318894273
# Confusion Matrix:
#  [[2551    1]
#  [  88    0]]
# FPR:  0.00039184952978056425
# FNR:  1.0

# %%
print("Marital 3 Section")
new_idx_df = marital_idx_3
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Marital 3 Section
# Accuracy:  0.9643426294820717
# Recall:  0.009831460674157303
# Precision:  0.3888888888888889
# F1 Score:  0.01917808219178082
# Gini Score code error.
# CV roc_auc_oof:  0.8392260748645977
# Confusion Matrix:
#  [[19357    11]
#  [  705     7]]
# FPR:  0.0005679471292854192
# FNR:  0.9901685393258427

# %%
print("Marital 4 Section")
new_idx_df = marital_idx_4
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Marital 4 Section
# Accuracy:  0.9737734165923283
# Recall:  0.013422818791946308
# Precision:  1.0
# F1 Score:  0.026490066225165563
# Gini Score code error.
# CV roc_auc_oof:  0.8667927926154816
# Confusion Matrix:
#  [[5456    0]
#  [ 147    2]]
# FPR:  0.0
# FNR:  0.9865771812080537

# %%
print("Marital 5 Section")
new_idx_df = marital_idx_5
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Marital 5 Section
# Accuracy:  0.9408163265306122
# Recall:  0.0
# Precision:  0.0
# F1 Score:  0.0
# Gini Score code error.
# CV roc_auc_oof:  0.8038746353504376
# Confusion Matrix:
#  [[461   0]
#  [ 29   0]]
# FPR:  0.0
# FNR:  1.0
# /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Marital Other Section")
new_idx_df = marital_idx_other
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Marital Other Section
# Accuracy:  0.9681865582541146
# Recall:  0.013238770685579196
# Precision:  0.6086956521739131
# F1 Score:  0.025913928736695974
# Gini Score code error.
# CV roc_auc_oof:  0.8284917071664143
# Confusion Matrix:
#  [[64034    18]
#  [ 2087    28]]
# FPR:  0.00028102166989321176
# FNR:  0.9867612293144208

# %%
print("Education 1 Section")
new_idx_df = education_idx_1
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Education 1 Section
# Accuracy:  0.9446308724832215
# Recall:  0.026415094339622643
# Precision:  0.5384615384615384
# F1 Score:  0.050359712230215826
# Gini Score code error.
# CV roc_auc_oof:  0.8131761215793245
# Confusion Matrix:
#  [[4497    6]
#  [ 258    7]]
# FPR:  0.0013324450366422385
# FNR:  0.9735849056603774

# %%
print("Education 2 Section")
new_idx_df = education_idx_2
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Education 2 Section
# Accuracy:  0.9738648654614485
# Recall:  0.007633587786259542
# Precision:  0.391304347826087
# F1 Score:  0.01497504159733777
# Gini Score code error.
# CV roc_auc_oof:  0.8569658228191674
# Confusion Matrix:
#  [[44110    14]
#  [ 1170     9]]
# FPR:  0.0003172876439126099
# FNR:  0.9923664122137404

# %%
print("Education 3 Section")
new_idx_df = education_idx_3
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Education 3 Section
# Accuracy:  0.967863475177305
# Recall:  0.013761467889908258
# Precision:  0.5454545454545454
# F1 Score:  0.026845637583892617
# Gini Score code error.
# CV roc_auc_oof:  0.8379077666503257
# Confusion Matrix:
#  [[13095     5]
#  [  430     6]]
# FPR:  0.0003816793893129771
# FNR:  0.9862385321100917

# %%
print("Education 4 Section")
new_idx_df = education_idx_4
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Education 4 Section
# Accuracy:  0.9584837545126353
# Recall:  0.0
# Precision:  0.0
# F1 Score:  0.0
# Gini Score code error.
# CV roc_auc_oof:  0.8282977155490051
# Confusion Matrix:
#  [[531   0]
#  [ 23   0]]
# FPR:  0.0
# FNR:  1.0
# /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Education Other Section")
new_idx_df = education_idx_other
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Education Other Section
# Accuracy:  0.9682545225955158
# Recall:  0.013153087321885276
# Precision:  0.5806451612903226
# F1 Score:  0.025723472668810293
# Gini Score code error.
# CV roc_auc_oof:  0.8287854099552195
# Confusion Matrix:
#  [[83139    26]
#  [ 2701    36]]
# FPR:  0.0003126315156616365
# FNR:  0.9868469126781148

# %%
for key in group_dfs:
    print(key)
    print(group_dfs[key].shape)
# Out:
# F & >60
# (18657, 519)
# F & 30-40
# (20770, 519)
# M & 50-60
# (7293, 519)
# F & <30
# (12360, 519)
# F & 40-50
# (19041, 519)
# M & >60
# (6862, 519)
# F & 50-60
# (15308, 519)
# M & 40-50
# (11377, 519)
# F & nan
# (8279, 519)
# M & <30
# (10944, 519)
# M & 30-40
# (15213, 519)
# M & nan
# (5638, 519)
# nan & 40-50
# (156, 519)
# nan & 30-40
# (371, 519)
# nan & <30
# (170, 519)
# nan & nan
# (72, 519)
# nan & 50-60
# (91, 519)
# nan & >60
# (64, 519)

# %%
#We pick the two most populus combinations for male and female each.
combo_1_f = group_dfs['F & 30-40']
combo_2_f = group_dfs['F & 40-50']
combo_1_m = group_dfs['M & 30-40']
combo_2_m = group_dfs['M & 40-50']

# %%
print("Female 30-40 Section")
new_idx_df = combo_1_f
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Female 30-40 Section
# Accuracy:  0.9702455464612422
# Recall:  0.011363636363636364
# Precision:  0.4375
# F1 Score:  0.022151898734177215
# Gini Score code error.
# CV roc_auc_oof:  0.8365281327286389
# Confusion Matrix:
#  [[20145     9]
#  [  609     7]]
# FPR:  0.00044656147662994937
# FNR:  0.9886363636363636

# %%
sns.heatmap(confusion_matrix(new_y_valid, new_valid_preds), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
print("Female 40-50 Section")
new_idx_df = combo_2_f
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Female 40-50 Section
# Accuracy:  0.972953101202668
# Recall:  0.017408123791102514
# Precision:  0.5625
# F1 Score:  0.033771106941838644
# Gini Score code error.
# CV roc_auc_oof:  0.8588784605636809
# Confusion Matrix:
#  [[18517     7]
#  [  508     9]]
# FPR:  0.0003778881451090477
# FNR:  0.9825918762088974

# %%
print("Male 30-40 Section")
new_idx_df = combo_1_m
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Male 30-40 Section
# Accuracy:  0.9622033786892789
# Recall:  0.01896551724137931
# Precision:  0.6470588235294118
# F1 Score:  0.03685092127303182
# Gini Score code error.
# CV roc_auc_oof:  0.8214742539889762
# Confusion Matrix:
#  [[14627     6]
#  [  569    11]]
# FPR:  0.00041003211918266933
# FNR:  0.9810344827586207

# %%
sns.heatmap(confusion_matrix(new_y_valid, new_valid_preds), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
print("Male 40-50 Section")
new_idx_df = combo_2_m
new_y_valid = new_idx_df['target']
new_valid_preds = model.predict(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))
new_valid_preds_proba = model.predict_proba(new_idx_df.drop(columns=["target", "case_id", "WEEK_NUM", 'age_bucket', 'group_age_sex']))[:,1]
print("Accuracy: ", accuracy_score(new_y_valid, new_valid_preds))
print("Recall: ", recall_score(new_y_valid, new_valid_preds))
print("Precision: ", precision_score(new_y_valid, new_valid_preds))
print("F1 Score: ", f1_score(new_y_valid, new_valid_preds))
new_oof_df = new_idx_df[["WEEK_NUM", "target"]].copy()
new_oof_df["pred_oof"] = new_valid_preds_proba
try:
    gini_score = gini_stability(new_oof_df, score_col="pred_oof")
    print("gini_score:\t", gini_score)
except:
    print("Gini Score code error.")
roc_auc_oof = roc_auc_score(new_y_valid, new_valid_preds_proba)
print("CV roc_auc_oof: ", roc_auc_oof)
tn, fp, fn, tp = confusion_matrix(new_y_valid, new_valid_preds).ravel()
print("Confusion Matrix: \n", confusion_matrix(new_y_valid, new_valid_preds))
print("FPR: ", fp/(fp+tn))
print("FNR: ", fn/(tp+fn))
# Out:
# Male 40-50 Section
# Accuracy:  0.9634350004394832
# Recall:  0.014388489208633094
# Precision:  0.5454545454545454
# F1 Score:  0.028037383177570093
# Gini Score code error.
# CV roc_auc_oof:  0.8334488613488771
# Confusion Matrix:
#  [[10955     5]
#  [  411     6]]
# FPR:  0.0004562043795620438
# FNR:  0.9856115107913669
